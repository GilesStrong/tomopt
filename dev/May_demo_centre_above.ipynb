# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from typing import *
import numpy as np
from functools import partial
from fastprogress import progress_bar
import pandas as pd
import h5py

from lumin.plotting.results import plot_roc

import torch
from torch import Tensor, nn
import torch.nn.functional as F
from torch._vmap_internals import _vmap as vmap

from tomopt.volume import *
from tomopt.muon import *
from tomopt.inference import *
from tomopt.optimisation import *
from tomopt.core import *
from tomopt.utils import *
from tomopt.plotting import *

import seaborn as sns
import matplotlib.pyplot as plt

# %%
DEVICE = torch.device("cpu")

# %%
NAME = 'central_above'

# %%
def area_cost(x:Tensor) -> Tensor:
    return F.relu(x)

# %%
def get_layers():
    layers = []
    lwh = Tensor([1,1,1])
    size = 0.1
    init_eff = 0.9
    init_res = 1e4
    n_panels = 4
    layers.append(PanelDetectorLayer(pos='above', lw=lwh[:2], z=1, size=2*size,
                                     panels=[DetectorPanel(res=init_res, eff=init_eff,
                                                      init_xyz=[0.5,0.5,1-(i*(2*size)/n_panels)], init_xy_span=[1.,1.],
                                                      area_cost_func=area_cost, device=DEVICE) for i in range(n_panels)]))
    for z in [0.8,0.7,0.6,0.5,0.4,0.3]:
        layers.append(PassiveLayer(lw=lwh[:2], z=z, size=size, device=DEVICE))
    layers.append(PanelDetectorLayer(pos='below', lw=lwh[:2], z=0.2, size=2*size,
                                     panels=[DetectorPanel(res=init_res, eff=init_eff,
                                                      init_xyz=[0.5,0.5,0.2-(i*(2*size)/n_panels)], init_xy_span=[1.,1.],
                                                      area_cost_func=area_cost, device=DEVICE) for i in range(n_panels)]))

    return nn.ModuleList(layers)

# %%
volume = Volume(get_layers())

# %%
volume.get_cost()
# Out:
# tensor(8., grad_fn=<AddBackward0>)

# %%
volume
# Out:
# Volume(
#   (layers): ModuleList(
#     (0): PanelDetectorLayer(
#       (panels): ModuleList(
#         (0): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5000, 0.5000]), z=tensor([1.]), and xy span tensor([1., 1.])
#         (1): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5000, 0.5000]), z=tensor([0.9500]), and xy span tensor([1., 1.])
#         (2): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5000, 0.5000]), z=tensor([0.9000]), and xy span tensor([1., 1.])
#         (3): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5000, 0.5000]), z=tensor([0.8500]), and xy span tensor([1., 1.])
#       )
#     )
#     (1): PassiveLayer()
#     (2): PassiveLayer()
#     (3): PassiveLayer()
#     (4): PassiveLayer()
#     (5): PassiveLayer()
#     (6): PassiveLayer()
#     (7): PanelDetectorLayer(
#       (panels): ModuleList(
#         (0): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5000, 0.5000]), z=tensor([0.2000]), and xy span tensor([1., 1.])
#         (1): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5000, 0.5000]), z=tensor([0.1500]), and xy span tensor([1., 1.])
#         (2): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5000, 0.5000]), z=tensor([0.1000]), and xy span tensor([1., 1.])
#         (3): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5000, 0.5000]), z=tensor([0.0500]), and xy span tensor([1., 1.])
#       )
#     )
#   )
# )

# %% [markdown]
# # Volume classifier

# %% [markdown]
# # Optimisation

# %%
from tomopt.optimisation import ULorryPassiveGenerator

# %%
u_volume = 12
passive_gen = ULorryPassiveGenerator(volume, u_volume=u_volume, u_prob=0.5, fill_frac=0.8, x0_lorry=X0['iron'], bkg_materials=['air', 'iron'])
trn_passives = PassiveYielder(passive_gen, n_passives=1)

# %%
from tomopt.optimisation import NoMoreNaNs, PanelMetricLogger, CostCoefWarmup, PanelOptConfig, MuonResampler

# %%
volume.get_cost()
# Out:
# tensor(8., grad_fn=<AddBackward0>)

# %%
wrapper = PanelVolumeWrapper(volume,
                             xy_pos_opt=partial(torch.optim.SGD, lr=1e-1),
                             z_pos_opt=partial(torch.optim.SGD, lr=1e-1),
                             xy_span_opt=partial(torch.optim.SGD, lr=1e2),
                             loss_func=VolumeClassLoss(x02id={0:0, 1:1}, target_budget=5, cost_coef=0.002, steep_budget=True),
                             partial_volume_inferer=partial(DenseBlockClassifierFromX0s, n_block_voxels=u_volume, partial_x0_inferer=PanelX0Inferer, volume=volume, ratio_offset=-1, ratio_coef=1))

# %% [markdown]
# ## Initial performance

# %%
test_passives = PassiveYielder(passive_gen, n_passives=200)

# %%
preds = wrapper.predict(test_passives,
                n_mu_per_volume=250,
                mu_bs=250,
                pred_cb=ClassPredHandler(x02id={0:0, 1:1}),
                cbs=[MuonResampler()])
# Out:
# /home/centos/volume/mode_muon_tomography/tomopt/inference/scattering.py:329: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   idxs = torch.combinations(torch.arange(0, unc.shape[-1]), with_replacement=True)

# %%
df_start = pd.DataFrame(np.array(preds).flatten().reshape(-1,2), columns=['pred', 'gen_target'])
# Out:
# <ipython-input-19-9804e60ffd94>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   df_start = pd.DataFrame(np.array(preds).flatten().reshape(-1,2), columns=['pred', 'gen_target'])

# %%
df_start['gen_target'] = df_start.gen_target.astype(int)

# %%
plot_roc(df_start, labels=['Start'])
# Out:
# {'Start': 0.8546365914786967}

# %% [markdown]
# ## Optimise

# %%
from tomopt.optimisation.callbacks.callback import Callback

class GradClip(Callback):
    def __init__(self, clip:float, clip_norm:bool=True):
        super().__init__()
        self.clip = clip
        self.func = nn.utils.clip_grad_norm_ if clip_norm else nn.utils.clip_grad_value_
        
    def on_backwards_end(self) -> None:
        if self.clip > 0: self.func(self.wrapper.parameters(), self.clip)

# %%
_ = wrapper.fit(n_epochs=120,
                passive_bs=1,
                n_mu_per_volume=250,
                mu_bs=250,
                trn_passives=trn_passives,
                val_passives=trn_passives,
                cbs=[
                    CostCoefWarmup(n_warmup=5), PanelOptConfig(n_warmup=5, xy_pos_rate=0.05, z_pos_rate=0.001, xy_span_rate=0.05),
                    MuonResampler(), NoMoreNaNs(), PanelMetricLogger()])
# Out:
# CostCoefWarmup: Freezing optimisation for 5 epochs
# PanelOptConfig: Freezing optimisation for 5 epochs
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.83% [1/120 00:32<1:04:23]
#     </div>
# /home/centos/volume/mode_muon_tomography/tomopt/optimisation/callbacks/monitors.py:211: UserWarning: Attempting to set identical left == right == 1.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(1 / self.n_trn_batches, x[-1])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-8d1b5a7af5f6> in <module>
# ----> 1 _ = wrapper.fit(n_epochs=120,
#       2                 passive_bs=1,
#       3                 n_mu_per_volume=250,
#       4                 mu_bs=250,
#       5                 trn_passives=trn_passives,
#
# ~/volume/mode_muon_tomography/tomopt/optimisation/wrapper/volume_wrapper.py in fit(self, n_epochs, passive_bs, n_mu_per_volume, mu_bs, trn_passives, val_passives, cbs, cb_savepath)
#     287             self.fit_params.epoch_bar = progress_bar(range(self.fit_params.n_epochs))
#     288             for e in self.fit_params.epoch_bar:
# --> 289                 self._fit_epoch()
#     290                 if self.fit_params.stop:
#     291                     break
#
# ~/volume/mode_muon_tomography/tomopt/optimisation/wrapper/volume_wrapper.py in _fit_epoch(self)
#     228         self.volume.train()
#     229         self.fit_params.state = "train"
# --> 230         run_epoch(self.fit_params.trn_passives)
#     231
#     232         # Validation
#
# ~/volume/mode_muon_tomography/tomopt/optimisation/wrapper/volume_wrapper.py in run_epoch(passives)
#     220             for c in self.fit_params.cbs:
#     221                 c.on_epoch_begin()
# --> 222             self._scan_volumes(passives)
#     223             for c in self.fit_params.cbs:
#     224                 c.on_epoch_end()
#
# ~/volume/mode_muon_tomography/tomopt/optimisation/wrapper/volume_wrapper.py in _scan_volumes(self, passives)
#     185             for c in self.fit_params.cbs:
#     186                 c.on_volume_begin()
# --> 187             self._scan_volume()
#     188             for c in self.fit_params.cbs:
#     189                 c.on_volume_end()
#
# ~/volume/mode_muon_tomography/tomopt/optimisation/wrapper/volume_wrapper.py in _scan_volume(self)
#     153             for c in self.fit_params.cbs:
#     154                 c.on_scatter_end()
# --> 155             self.fit_params.volume_inferer.add_scatters(self.fit_params.sb)
#     156             for c in self.fit_params.cbs:
#     157                 c.on_mu_batch_end()
#
# ~/volume/mode_muon_tomography/tomopt/inference/volume.py in add_scatters(self, scatters)
#     465
#     466     def add_scatters(self, scatters: AbsScatterBatch) -> None:
# --> 467         self.x0_inferer.add_scatters(scatters)
#     468         self.efficiencies.append(self.compute_efficiency(scatters=scatters))
#     469
#
# ~/volume/mode_muon_tomography/tomopt/inference/volume.py in add_scatters(self, scatters)
#      58
#      59         # Get X0 prediction for all voxels
# ---> 60         p, w = self.get_voxel_x0_preds(
#      61             x0_dtheta=self.x0_dthetas[-1],
#      62             x0_dtheta_unc=self.x0_dtheta_uncs[-1],
#
# ~/volume/mode_muon_tomography/tomopt/inference/volume.py in get_voxel_x0_preds(self, x0_dtheta, x0_dtheta_unc, x0_dxy, x0_dxy_unc, efficiency, scatters)
#     157         """
#     158
# --> 159         loc, loc_unc = scatters.location, scatters.location_unc  # loc is (x,y,z)
#     160         # Only consider non-NaN predictions
#     161         mask = ((loc == loc).prod(1) * (loc_unc == loc_unc).prod(1)).bool()
#
# ~/volume/mode_muon_tomography/tomopt/inference/scattering.py in location_unc(self)
#     342     def location_unc(self) -> Tensor:
#     343         if self._loc_unc is None:
# --> 344             self._loc_unc = self._compute_out_var_unc(self.location)
#     345         return self._loc_unc
#     346
#
# ~/volume/mode_muon_tomography/tomopt/inference/scattering.py in _compute_out_var_unc(self, var)
#     322
#     323         # Compute dvar/dhits
# --> 324         jac = torch.nan_to_num(jacobian(var, self.reco_hits)).sum(2)
#     325         unc = torch.where(torch.isinf(self.hit_uncs), torch.tensor([0], device=self.device).type(self.hit_uncs.type()), self.hit_uncs)[:, None]
#     326         jac, unc = jac.reshape(jac.shape[0], jac.shape[1], -1), unc.reshape(unc.shape[0], unc.shape[1], -1)
#
# ~/volume/mode_muon_tomography/tomopt/utils.py in jacobian(y, x, create_graph, allow_unused)
#      25         return torch.autograd.grad(flat_y, x, v, retain_graph=True, create_graph=create_graph, allow_unused=allow_unused)[0].reshape(x.shape)
#      26
# ---> 27     return vmap(get_vjp)(torch.eye(len(flat_y), device=y.device)).reshape(y.shape + x.shape)
#      28
#      29
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/torch/_vmap_internals.py in wrapped(*args)
#     261         try:
#     262             batched_inputs, batch_size = _create_batched_inputs(in_dims, args, vmap_level, func)
# --> 263             batched_outputs = func(*batched_inputs)
#     264             _validate_outputs(batched_outputs, func)
#     265             return _unwrap_batched(batched_outputs, out_dims, vmap_level, batch_size, func)
#
# ~/volume/mode_muon_tomography/tomopt/utils.py in get_vjp(v)
#      23
#      24     def get_vjp(v: Tensor) -> Tensor:
# ---> 25         return torch.autograd.grad(flat_y, x, v, retain_graph=True, create_graph=create_graph, allow_unused=allow_unused)[0].reshape(x.shape)
#      26
#      27     return vmap(get_vjp)(torch.eye(len(flat_y), device=y.device)).reshape(y.shape + x.shape)
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     232         retain_graph = create_graph
#     233
# --> 234     return Variable._execution_engine.run_backward(
#     235         outputs, grad_outputs_, retain_graph, create_graph,
#     236         inputs, allow_unused, accumulate_grad=False)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7fb282998040> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     248
#     249     if 'png' in formats:
# --> 250         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     251     if 'retina' in formats or 'png2x' in formats:
#     252         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     132         FigureCanvasBase(fig)
#     133
# --> 134     fig.canvas.print_figure(bytes_io, **kw)
#     135     data = bytes_io.getvalue()
#     136     if fmt == 'svg':
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2098                            else suppress())
#    2099                     with ctx:
# -> 2100                         self.figure.draw(renderer)
#    2101                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2102                     bbox_inches = self.figure.get_tightbbox(renderer,
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1724             renderer.open_group('figure', gid=self.get_gid())
#    1725             if self.get_constrained_layout() and self.axes:
# -> 1726                 self.execute_constrained_layout(renderer)
#    1727             if self.get_tight_layout() and self.axes:
#    1728                 try:
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib/figure.py in execute_constrained_layout(self, renderer)
#    2444         if renderer is None:
#    2445             renderer = layoutbox.get_renderer(fig)
# -> 2446         do_constrained_layout(fig, renderer, h_pad, w_pad, hspace, wspace)
#    2447
#    2448     @cbook._delete_parameter("3.2", "renderer")
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib/_constrained_layout.py in do_constrained_layout(fig, renderer, h_pad, w_pad, hspace, wspace)
#     166                 # make margins for each layout box based on the size of
#     167                 # the decorators.
# --> 168                 _make_layout_margins(ax, renderer, h_pad, w_pad)
#     169
#     170         # do layout for suptitle.
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib/_constrained_layout.py in _make_layout_margins(ax, renderer, h_pad, w_pad)
#     267     invTransFig = fig.transFigure.inverted().transform_bbox
#     268     pos = ax.get_position(original=True)
# --> 269     tightbbox = ax.get_tightbbox(renderer=renderer)
#     270     if tightbbox is None:
#     271         bbox = pos
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4359                     # this artist
#    4360                     continue
# -> 4361             bbox = a.get_tightbbox(renderer)
#    4362             if (bbox is not None
#    4363                     and 0 < bbox.width < np.inf
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib/artist.py in get_tightbbox(self, renderer)
#     280             The enclosing bounding box (in figure pixel co-ordinates).
#     281         """
# --> 282         bbox = self.get_window_extent(renderer)
#     283         if self.get_clip_on():
#     284             clip_box = self.get_clip_box()
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib/spines.py in get_window_extent(self, renderer)
#     171         # make sure the location is updated so that transforms etc are correct:
#     172         self._adjust_location()
# --> 173         bb = super().get_window_extent(renderer=renderer)
#     174         if self.axis is None:
#     175             return bb
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib/patches.py in get_window_extent(self, renderer)
#     607
#     608     def get_window_extent(self, renderer=None):
# --> 609         return self.get_path().get_extents(self.get_transform())
#     610
#     611     def _convert_xy_units(self, xy):
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib/path.py in get_extents(self, transform)
#     535         path = self
#     536         if transform is not None:
# --> 537             transform = transform.frozen()
#     538             if not transform.is_affine:
#     539                 path = self.transformed(transform)
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib/transforms.py in frozen(self)
#    2158     def frozen(self):
#    2159         # docstring inherited
# -> 2160         return blended_transform_factory(self._x.frozen(), self._y.frozen())
#    2161
#    2162     def transform_non_affine(self, points):
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib/transforms.py in blended_transform_factory(x_transform, y_transform)
#    2274     if (isinstance(x_transform, Affine2DBase)
#    2275         and isinstance(y_transform, Affine2DBase)):
# -> 2276         return BlendedAffine2D(x_transform, y_transform)
#    2277     return BlendedGenericTransform(x_transform, y_transform)
#    2278
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib/transforms.py in __init__(self, x_transform, y_transform, **kwargs)
#    2233         """
#    2234         is_affine = x_transform.is_affine and y_transform.is_affine
# -> 2235         is_separable = x_transform.is_separable and y_transform.is_separable
#    2236         is_correct = is_affine and is_separable
#    2237         if not is_correct:
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/matplotlib/transforms.py in is_separable(self)
#    1766         return Affine2D(self.get_matrix().copy())
#    1767
# -> 1768     @property
#    1769     def is_separable(self):
#    1770         mtx = self.get_matrix()
#
# KeyboardInterrupt:

# %%
wrapper.save(f'may_demo/{NAME}_0.pt')

# %%
volume.get_cost()

# %% [markdown]
# ## Optimised performance

# %%
preds = wrapper.predict(test_passives,
                n_mu_per_volume=250,
                mu_bs=250,
                pred_cb=ClassPredHandler(x02id={0:0, 1:1}),
                cbs=[MuonResampler()])

# %%
df_opt = pd.DataFrame(np.array(preds).flatten().reshape(-1,2), columns=['pred', 'gen_target'])

# %%
df_opt['gen_target'] = df_opt.gen_target.astype(int)

# %%
plot_roc((df_start, df_opt), labels=['Start', 'Optimised'])
