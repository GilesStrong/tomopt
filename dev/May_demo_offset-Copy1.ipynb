# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from typing import *
import numpy as np
from functools import partial
from fastprogress import progress_bar
import pandas as pd
import h5py

from lumin.plotting.results import plot_roc

import torch
from torch import Tensor, nn
import torch.nn.functional as F
from torch._vmap_internals import _vmap as vmap

from tomopt.volume import *
from tomopt.muon import *
from tomopt.inference import *
from tomopt.optimisation import *
from tomopt.core import *
from tomopt.utils import *
from tomopt.plotting import *

import seaborn as sns
import matplotlib.pyplot as plt

# %%
DEVICE = torch.device("cpu")

# %%
def area_cost(x:Tensor) -> Tensor:
    return F.relu(x)

# %%
def get_layers():
    layers = []
    lwh = Tensor([1,1,1])
    size = 0.1
    init_eff = 0.9
    init_res = 1e4
    n_panels = 4
    layers.append(PanelDetectorLayer(pos='above', lw=lwh[:2], z=1, size=2*size,
                                     panels=[DetectorPanel(res=init_res, eff=init_eff,
                                                      init_xyz=[0.0,0.0,1-(i*(2*size)/n_panels)], init_xy_span=[0.5,0.5],
                                                      area_cost_func=area_cost, device=DEVICE) for i in range(n_panels)]))
    for z in [0.8,0.7,0.6,0.5,0.4,0.3]:
        layers.append(PassiveLayer(lw=lwh[:2], z=z, size=size, device=DEVICE))
    layers.append(PanelDetectorLayer(pos='below', lw=lwh[:2], z=0.2, size=2*size,
                                     panels=[DetectorPanel(res=init_res, eff=init_eff,
                                                      init_xyz=[0.0,0.0,0.2-(i*(2*size)/n_panels)], init_xy_span=[0.5,0.5],
                                                      area_cost_func=area_cost, device=DEVICE) for i in range(n_panels)]))

    return nn.ModuleList(layers)

# %%
volume = Volume(get_layers())

# %%
volume
# Out:
# Volume(
#   (layers): ModuleList(
#     (0): PanelDetectorLayer(
#       (panels): ModuleList(
#         (0): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0., 0.]), z=tensor([1.]), and xy span tensor([0.5000, 0.5000])
#         (1): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0., 0.]), z=tensor([0.9500]), and xy span tensor([0.5000, 0.5000])
#         (2): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0., 0.]), z=tensor([0.9000]), and xy span tensor([0.5000, 0.5000])
#         (3): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0., 0.]), z=tensor([0.8500]), and xy span tensor([0.5000, 0.5000])
#       )
#     )
#     (1): PassiveLayer()
#     (2): PassiveLayer()
#     (3): PassiveLayer()
#     (4): PassiveLayer()
#     (5): PassiveLayer()
#     (6): PassiveLayer()
#     (7): PanelDetectorLayer(
#       (panels): ModuleList(
#         (0): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0., 0.]), z=tensor([0.2000]), and xy span tensor([0.5000, 0.5000])
#         (1): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0., 0.]), z=tensor([0.1500]), and xy span tensor([0.5000, 0.5000])
#         (2): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0., 0.]), z=tensor([0.1000]), and xy span tensor([0.5000, 0.5000])
#         (3): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0., 0.]), z=tensor([0.0500]), and xy span tensor([0.5000, 0.5000])
#       )
#     )
#   )
# )

# %% [markdown]
# # Volume classifier

# %% [markdown]
# # Optimisation

# %%
from tomopt.optimisation import ULorryPassiveGenerator

# %%
u_volume = 12
passive_gen = ULorryPassiveGenerator(volume, u_volume=u_volume, u_prob=0.5, fill_frac=0.8, x0_lorry=X0['iron'], bkg_materials=['air', 'iron'])
trn_passives = PassiveYielder(passive_gen, n_passives=4)

# %%
from tomopt.optimisation import NoMoreNaNs, PanelMetricLogger, CostCoefWarmup, PanelOptConfig, MuonResampler

# %%
volume.get_cost()
# Out:
# tensor(2., grad_fn=<AddBackward0>)

# %%
wrapper = PanelVolumeWrapper(volume,
                             xy_pos_opt=partial(torch.optim.SGD, lr=5e4),
                             z_pos_opt=partial(torch.optim.SGD, lr=5e3),
                             xy_span_opt=partial(torch.optim.SGD, lr=1e4),
                             loss_func=VolumeClassLoss(x02id={0:0, 1:1}, target_budget=5),
                             partial_volume_inferer=partial(DenseBlockClassifierFromX0s, n_block_voxels=u_volume, partial_x0_inferer=PanelX0Inferer, volume=volume, ratio_offset=-1, ratio_coef=1))

# %%
wrapper.load('may_demo/offset_0.pt')

# %%
for i,p in enumerate(volume.get_detectors()[0].panels):
    p.z.data = Tensor([1-(i*(2*0.1)/4)])

# %%
for i,p in enumerate(volume.get_detectors()[1].panels):
    p.z.data = Tensor([0.2-(i*(2*0.1)/4)])

# %%
volume
# Out:
# Volume(
#   (layers): ModuleList(
#     (0): PanelDetectorLayer(
#       (panels): ModuleList(
#         (0): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5472, 0.4661]), z=tensor([1.]), and xy span tensor([0.5315, 0.6826])
#         (1): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5417, 0.4275]), z=tensor([0.9500]), and xy span tensor([0.5342, 0.6833])
#         (2): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.4939, 0.4929]), z=tensor([0.9000]), and xy span tensor([0.5601, 0.5374])
#         (3): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5108, 0.3344]), z=tensor([0.8500]), and xy span tensor([0.6075, 0.5251])
#       )
#     )
#     (1): PassiveLayer()
#     (2): PassiveLayer()
#     (3): PassiveLayer()
#     (4): PassiveLayer()
#     (5): PassiveLayer()
#     (6): PassiveLayer()
#     (7): PanelDetectorLayer(
#       (panels): ModuleList(
#         (0): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.4732, 0.4902]), z=tensor([0.2000]), and xy span tensor([0.6233, 0.6108])
#         (1): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.4791, 0.4788]), z=tensor([0.1500]), and xy span tensor([0.6201, 0.6224])
#         (2): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.4689, 0.4528]), z=tensor([0.1000]), and xy span tensor([0.6015, 0.6466])
#         (3): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5204, 0.4274]), z=tensor([0.0500]), and xy span tensor([0.5968, 0.5977])
#       )
#     )
#   )
# )

# %% [markdown]
# ## Initial performance

# %%
test_passives = PassiveYielder(passive_gen, n_passives=200)

# %%
preds = wrapper.predict(test_passives,
                n_mu_per_volume=250,
                mu_bs=250,
                pred_cb=ClassPredHandler(x02id={0:0, 1:1}),
                cbs=[MuonResampler()])
# Out:
# /home/centos/volume/mode_muon_tomography/tomopt/inference/scattering.py:329: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   idxs = torch.combinations(torch.arange(0, unc.shape[-1]), with_replacement=True)

# %%
df_start = pd.DataFrame(np.array(preds).flatten().reshape(-1,2), columns=['pred', 'gen_target'])
# Out:
# <ipython-input-23-9804e60ffd94>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   df_start = pd.DataFrame(np.array(preds).flatten().reshape(-1,2), columns=['pred', 'gen_target'])

# %%
df_start['gen_target'] = df_start.gen_target.astype(int)

# %%
plot_roc(df_start, labels=['Regular sep'])
# Out:
# {'Regular sep': 0.8238474092207262}

# %% [markdown]
# ## Optimise

# %%
_ = wrapper.fit(n_epochs=120,
                passive_bs=4,
                n_mu_per_volume=250,
                mu_bs=250,
                trn_passives=trn_passives,
                val_passives=trn_passives,
                cbs=[CostCoefWarmup(n_warmup=5), PanelOptConfig(n_warmup=5, xy_pos_rate=0.05, z_pos_rate=0.001, xy_span_rate=0.05), MuonResampler(), NoMoreNaNs(),PanelMetricLogger()])
# Out:
# CostCoefWarmup: Freezing optimisation for 5 epochs
# PanelOptConfig: Freezing optimisation for 5 epochs
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.83% [1/120 00:10<21:10]
#     </div>
# /home/centos/volume/mode_muon_tomography/tomopt/inference/scattering.py:329: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   idxs = torch.combinations(torch.arange(0, unc.shape[-1]), with_replacement=True)
# Automatically setting cost coefficient to 0.013463515788316727
# /home/centos/volume/mode_muon_tomography/tomopt/optimisation/callbacks/monitors.py:211: UserWarning: Attempting to set identical left == right == 1.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(1 / self.n_trn_batches, x[-1])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-47c657a3cd3d> in <module>
# ----> 1 _ = wrapper.fit(n_epochs=120,
#       2                 passive_bs=4,
#       3                 n_mu_per_volume=250,
#       4                 mu_bs=250,
#       5                 trn_passives=trn_passives,
#
# ~/volume/mode_muon_tomography/tomopt/optimisation/wrapper/volume_wrapper.py in fit(self, n_epochs, passive_bs, n_mu_per_volume, mu_bs, trn_passives, val_passives, cbs, cb_savepath)
#     287             self.fit_params.epoch_bar = progress_bar(range(self.fit_params.n_epochs))
#     288             for e in self.fit_params.epoch_bar:
# --> 289                 self._fit_epoch()
#     290                 if self.fit_params.stop:
#     291                     break
#
# ~/volume/mode_muon_tomography/tomopt/optimisation/wrapper/volume_wrapper.py in _fit_epoch(self)
#     228         self.volume.train()
#     229         self.fit_params.state = "train"
# --> 230         run_epoch(self.fit_params.trn_passives)
#     231
#     232         # Validation
#
# ~/volume/mode_muon_tomography/tomopt/optimisation/wrapper/volume_wrapper.py in run_epoch(passives)
#     220             for c in self.fit_params.cbs:
#     221                 c.on_epoch_begin()
# --> 222             self._scan_volumes(passives)
#     223             for c in self.fit_params.cbs:
#     224                 c.on_epoch_end()
#
# ~/volume/mode_muon_tomography/tomopt/optimisation/wrapper/volume_wrapper.py in _scan_volumes(self, passives)
#     185             for c in self.fit_params.cbs:
#     186                 c.on_volume_begin()
# --> 187             self._scan_volume()
#     188             for c in self.fit_params.cbs:
#     189                 c.on_volume_end()
#
# ~/volume/mode_muon_tomography/tomopt/optimisation/wrapper/volume_wrapper.py in _scan_volume(self)
#     153             for c in self.fit_params.cbs:
#     154                 c.on_scatter_end()
# --> 155             self.fit_params.volume_inferer.add_scatters(self.fit_params.sb)
#     156             for c in self.fit_params.cbs:
#     157                 c.on_mu_batch_end()
#
# ~/volume/mode_muon_tomography/tomopt/inference/volume.py in add_scatters(self, scatters)
#     465
#     466     def add_scatters(self, scatters: AbsScatterBatch) -> None:
# --> 467         self.x0_inferer.add_scatters(scatters)
#     468         self.efficiencies.append(self.compute_efficiency(scatters=scatters))
#     469
#
# ~/volume/mode_muon_tomography/tomopt/inference/volume.py in add_scatters(self, scatters)
#      58
#      59         # Get X0 prediction for all voxels
# ---> 60         p, w = self.get_voxel_x0_preds(
#      61             x0_dtheta=self.x0_dthetas[-1],
#      62             x0_dtheta_unc=self.x0_dtheta_uncs[-1],
#
# ~/volume/mode_muon_tomography/tomopt/inference/volume.py in get_voxel_x0_preds(self, x0_dtheta, x0_dtheta_unc, x0_dxy, x0_dxy_unc, efficiency, scatters)
#     191
#     192             prob = (
# --> 193                 torch.stack([comp_int(l, l + self.volume.passive_size, dists) for l in self.volume.edges.unbind()])
#     194                 .transpose(-1, -2)
#     195                 .reshape(shp_xyz)
#
# ~/volume/mode_muon_tomography/tomopt/inference/volume.py in <listcomp>(.0)
#     191
#     192             prob = (
# --> 193                 torch.stack([comp_int(l, l + self.volume.passive_size, dists) for l in self.volume.edges.unbind()])
#     194                 .transpose(-1, -2)
#     195                 .reshape(shp_xyz)
#
# ~/volume/mode_muon_tomography/tomopt/inference/volume.py in comp_int(low, high, dists)
#     188
#     189             def comp_int(low: Tensor, high: Tensor, dists: Dict[str, Normal]) -> Tensor:
# --> 190                 return torch.prod(torch.stack([dists[d].cdf(high[i]) - dists[d].cdf(low[i]) for i, d in enumerate(dists)]), dim=0)
#     191
#     192             prob = (
#
# ~/volume/mode_muon_tomography/tomopt/inference/volume.py in <listcomp>(.0)
#     188
#     189             def comp_int(low: Tensor, high: Tensor, dists: Dict[str, Normal]) -> Tensor:
# --> 190                 return torch.prod(torch.stack([dists[d].cdf(high[i]) - dists[d].cdf(low[i]) for i, d in enumerate(dists)]), dim=0)
#     191
#     192             prob = (
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/torch/distributions/normal.py in cdf(self, value)
#      79     def cdf(self, value):
#      80         if self._validate_args:
# ---> 81             self._validate_sample(value)
#      82         return 0.5 * (1 + torch.erf((value - self.loc) * self.scale.reciprocal() / math.sqrt(2)))
#      83
#
# ~/volume/anaconda3/envs/tomopt/lib/python3.8/site-packages/torch/distributions/distribution.py in _validate_sample(self, value)
#     266
#     267         event_dim_start = len(value.size()) - len(self._event_shape)
# --> 268         if value.size()[event_dim_start:] != self._event_shape:
#     269             raise ValueError('The right-most size of value must match event_shape: {} vs {}.'.
#     270                              format(value.size(), self._event_shape))
#
# KeyboardInterrupt:

# %%
wrapper.save('may_demo/offset_0.pt')

# %%
volume.get_cost()
# Out:
# tensor(2.8601, grad_fn=<AddBackward0>)

# %% [markdown]
# ## Optimised performance

# %%
wrapper.load('may_demo/offset_0.pt')

# %%
preds = wrapper.predict(test_passives,
                n_mu_per_volume=250,
                mu_bs=250,
                pred_cb=ClassPredHandler(x02id={0:0, 1:1}),
                cbs=[MuonResampler()])

# %%
df_opt = pd.DataFrame(np.array(preds).flatten().reshape(-1,2), columns=['pred', 'gen_target'])
# Out:
# <ipython-input-29-282cd680ea81>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   df_opt = pd.DataFrame(np.array(preds).flatten().reshape(-1,2), columns=['pred', 'gen_target'])

# %%
df_opt['gen_target'] = df_opt.gen_target.astype(int)

# %%
plot_roc((df_start, df_opt), labels=['Regular sep', 'Optimised sep'])
# Out:
# {'Regular sep': 0.8238474092207262, 'Optimised sep': 0.8917171717171718}
