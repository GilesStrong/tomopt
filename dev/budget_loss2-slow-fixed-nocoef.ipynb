# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
from functools import partial
import matplotlib.pyplot as plt
import seaborn as sns

import torch
from torch import Tensor, nn
from torch.nn import functional as F

from tomopt.core import *
from tomopt.volume import *
from tomopt.inference import *
from tomopt.muon import *
from tomopt.optimisation import *

# %%
DEVICE = torch.device('cpu')

# %%
def area_cost(x:Tensor) -> Tensor:
    return F.relu(x)

x = torch.linspace(-1, 1)
plt.plot(x, area_cost(x))
# Out:
# <ipython-input-4-5787166f89b9>:4: UserWarning: Not providing a value for linspace's steps is deprecated and will throw a runtime error in a future release. This warning will appear only once per process. (Triggered internally at  ../aten/src/ATen/native/RangeFactories.cpp:23.)
#   x = torch.linspace(-1, 1)

# %%
def area_coef(x:Tensor, targ:float) -> Tensor:
    return (2*torch.sigmoid(10*(x-targ)/targ)) + F.relu(x-targ)/targ

x = torch.linspace(-1, 2)
plt.plot(x, area_coef(x, 0.8))

# %%
from typing import *

class DetectorLoss(nn.Module):
    def __init__(self, target_budget: Optional[Union[Tensor, float]]=None, budget_smoothing:Union[Tensor, float]=10):
        super().__init__()
        self.target_budget, self.budget_smoothing = target_budget, budget_smoothing
        self.sub_losses: Dict[str, Tensor] = {}  # Store subcomponents in dict for telemetry
            
    def _get_budget_coef(self, cost: Tensor) -> Union[float, Tensor]:
        r"""Switch-on near target budget, plus linear increase above budget"""
        if self.target_budget == 0:
            return 0
        d = cost - self.target_budget
        return (2 * torch.sigmoid(self.budget_smoothing * d / self.target_budget)) + (F.relu(d) / self.target_budget)

    def forward(self, pred_x0: Tensor, pred_weight: Tensor, volume: Volume) -> Tensor:
        true_x0 = volume.get_rad_cube()
        inference = torch.mean((pred_x0 - true_x0).pow(2) / pred_weight)
        self.sub_losses["error"] = inference
        cost = volume.get_cost()
        self.sub_losses["cost"] = self._get_budget_coef(cost) * self.sub_losses["error"]
        print(f'Loss details: cost {cost:.3E}, budget coef {self._get_budget_coef(cost):.3E}. error loss {self.sub_losses["error"]:.3E}, cost loss {self.sub_losses["cost"]:.3E}')
        return self.sub_losses["error"] + self.sub_losses["cost"]

# %%
def get_layers():
    layers = []
    lwh = Tensor([1,1,1])
    size = 0.1
    init_eff = 0.5
    init_res = 1000
    n_panels = 4
    layers.append(PanelDetectorLayer(pos='above', lw=lwh[:2], z=1, size=2*size,
                                     panels=[DetectorPanel(res=init_res, eff=init_eff,
                                                      init_xyz=[0.5,0.5,1-(i*(2*size)/n_panels)], init_xy_span=[1.0,1.0],
                                                      area_cost_func=area_cost, device=DEVICE) for i in range(n_panels)]))
    for z in [0.8,0.7,0.6,0.5,0.4,0.3]:
        layers.append(PassiveLayer(lw=lwh[:2], z=z, size=size, device=DEVICE))
    layers.append(PanelDetectorLayer(pos='below', lw=lwh[:2], z=0.2, size=2*size,
                                     panels=[DetectorPanel(res=init_res, eff=init_eff,
                                                      init_xyz=[0.5,0.5,0.2-(i*(2*size)/n_panels)], init_xy_span=[1.0,1.0],
                                                      area_cost_func=area_cost, device=DEVICE) for i in range(n_panels)]))

    return nn.ModuleList(layers)

# %%
volume = Volume(get_layers())
volume
# Out:
# Volume(
#   (layers): ModuleList(
#     (0): PanelDetectorLayer(
#       (panels): ModuleList(
#         (0): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5000, 0.5000]), z=tensor([1.]), and xy span tensor([1., 1.])
#         (1): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5000, 0.5000]), z=tensor([0.9500]), and xy span tensor([1., 1.])
#         (2): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5000, 0.5000]), z=tensor([0.9000]), and xy span tensor([1., 1.])
#         (3): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5000, 0.5000]), z=tensor([0.8500]), and xy span tensor([1., 1.])
#       )
#     )
#     (1): PassiveLayer()
#     (2): PassiveLayer()
#     (3): PassiveLayer()
#     (4): PassiveLayer()
#     (5): PassiveLayer()
#     (6): PassiveLayer()
#     (7): PanelDetectorLayer(
#       (panels): ModuleList(
#         (0): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5000, 0.5000]), z=tensor([0.2000]), and xy span tensor([1., 1.])
#         (1): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5000, 0.5000]), z=tensor([0.1500]), and xy span tensor([1., 1.])
#         (2): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5000, 0.5000]), z=tensor([0.1000]), and xy span tensor([1., 1.])
#         (3): <class 'tomopt.volume.panel.DetectorPanel'> located at xy=tensor([0.5000, 0.5000]), z=tensor([0.0500]), and xy span tensor([1., 1.])
#       )
#     )
#   )
# )

# %%
volume.get_cost()
# Out:
# tensor(8., grad_fn=<AddBackward0>)

# %%
wrapper = PanelVolumeWrapper(volume,
                             xy_pos_opt=partial(torch.optim.SGD, lr=1e2),
                             z_pos_opt=partial(torch.optim.SGD, lr=5e3),
                             xy_span_opt=partial(torch.optim.SGD, lr=1e5),
                             loss_func=DetectorLoss(target_budget=0.8))  # Loss is precision + cost_coef*detector cost, balance coef as required or leave as None to automatically balance on first batch

# %%
def arb_rad_length(*,z:float, lw:Tensor, size:float) -> float:
    rad_length = torch.ones(list((lw/size).long()))*X0['beryllium']
    if z >= 0.4 and z <= 0.5: rad_length[5:,5:] = X0['lead']
    return rad_length

# %%
passives = PassiveYielder([arb_rad_length])

# %%
_ = wrapper.fit(n_epochs=10,
                passive_bs=1,
                n_mu_per_volume=1000,
                mu_bs=100,
                trn_passives=passives,
                val_passives=passives,
                cbs=[PanelMetricLogger()])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       80.00% [8/10 15:10<03:47]
#     </div>
# Loss details: cost 8.000E+00, budget coef 1.100E+01. error loss 2.678E-06, cost loss 2.946E-05
# Loss details: cost 7.238E+00, budget coef 1.005E+01. error loss 1.125E-05, cost loss 1.130E-04
# /Users/giles/cernbox/mode_muon_tomography/tomopt/optimisation/callbacks/monitors.py:212: UserWarning: Attempting to set identical left == right == 1.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(1 / self.n_trn_batches, x[-1])
# Loss details: cost 7.238E+00, budget coef 1.005E+01. error loss 1.404E-05, cost loss 1.411E-04
# Loss details: cost 6.422E+00, budget coef 9.027E+00. error loss 4.067E-03, cost loss 3.672E-02
# Loss details: cost 6.422E+00, budget coef 9.027E+00. error loss 8.568E-06, cost loss 7.735E-05
# Loss details: cost 5.422E+00, budget coef 7.777E+00. error loss 2.705E-03, cost loss 2.104E-02
# Loss details: cost 5.422E+00, budget coef 7.777E+00. error loss 3.071E-06, cost loss 2.388E-05
# Loss details: cost 6.647E+00, budget coef 9.309E+00. error loss 4.098E-05, cost loss 3.815E-04
# Loss details: cost 6.647E+00, budget coef 9.309E+00. error loss 6.309E-06, cost loss 5.873E-05
# Loss details: cost 6.067E+00, budget coef 8.584E+00. error loss 1.317E-02, cost loss 1.131E-01
# Loss details: cost 6.067E+00, budget coef 8.584E+00. error loss 1.430E-05, cost loss 1.228E-04
# Loss details: cost 4.649E+00, budget coef 6.812E+00. error loss 2.654E-01, cost loss 1.808E+00
# Loss details: cost 4.649E+00, budget coef 6.812E+00. error loss 5.610E-05, cost loss 3.821E-04
# Loss details: cost 4.010E+00, budget coef 6.013E+00. error loss 7.377E+10, cost loss 4.435E+11
# Loss details: cost 4.010E+00, budget coef 6.013E+00. error loss 2.154E+00, cost loss 1.295E+01
# Warning: unable to scan volume with prescribed number of muons.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/cernbox/mode_muon_tomography/tomopt/volume/panel.py in get_gauss(self)
#      48         try:
# ---> 49             return torch.distributions.Normal(self.xy, self.xy_span)  # maybe upscale span?
#      50         except ValueError:
#
# ~/anaconda3/envs/tomopt/lib/python3.8/site-packages/torch/distributions/normal.py in __init__(self, loc, scale, validate_args)
#      49             batch_shape = self.loc.size()
# ---> 50         super(Normal, self).__init__(batch_shape, validate_args=validate_args)
#      51
#
# ~/anaconda3/envs/tomopt/lib/python3.8/site-packages/torch/distributions/distribution.py in __init__(self, batch_shape, event_shape, validate_args)
#      52                 if not constraint.check(getattr(self, param)).all():
# ---> 53                     raise ValueError("The parameter {} has invalid values".format(param))
#      54         super(Distribution, self).__init__()
#
# ValueError: The parameter loc has invalid values
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-623b68d49763> in <module>
# ----> 1 _ = wrapper.fit(n_epochs=10,
#       2                 passive_bs=1,
#       3                 n_mu_per_volume=1000,
#       4                 mu_bs=100,
#       5                 trn_passives=passives,
#
# ~/cernbox/mode_muon_tomography/tomopt/optimisation/wrapper/volume_wrapper.py in fit(self, n_epochs, passive_bs, n_mu_per_volume, mu_bs, trn_passives, val_passives, cbs, cb_savepath)
#     300             self.fit_params.epoch_bar = progress_bar(range(self.fit_params.n_epochs))
#     301             for e in self.fit_params.epoch_bar:
# --> 302                 self._fit_epoch()
#     303                 if self.fit_params.stop:
#     304                     break
#
# ~/cernbox/mode_muon_tomography/tomopt/optimisation/wrapper/volume_wrapper.py in _fit_epoch(self)
#     241         self.volume.train()
#     242         self.fit_params.state = "train"
# --> 243         run_epoch(self.fit_params.trn_passives)
#     244
#     245         # Validation
#
# ~/cernbox/mode_muon_tomography/tomopt/optimisation/wrapper/volume_wrapper.py in run_epoch(passives)
#     233             for c in self.fit_params.cbs:
#     234                 c.on_epoch_begin()
# --> 235             self._scan_volumes(passives)
#     236             for c in self.fit_params.cbs:
#     237                 c.on_epoch_end()
#
# ~/cernbox/mode_muon_tomography/tomopt/optimisation/wrapper/volume_wrapper.py in _scan_volumes(self, passives)
#     198             for c in self.fit_params.cbs:
#     199                 c.on_volume_begin()
# --> 200             self._scan_volume()
#     201             for c in self.fit_params.cbs:
#     202                 c.on_volume_end()
#
# ~/cernbox/mode_muon_tomography/tomopt/optimisation/wrapper/volume_wrapper.py in _scan_volume(self)
#     147             for c in self.fit_params.cbs:
#     148                 c.on_mu_batch_begin()
# --> 149             self.volume(self.fit_params.mu)
#     150             self.fit_params.sb = self.partial_scatter_inferer(self.fit_params.mu, self.volume)
#     151             for c in self.fit_params.cbs:
#
# ~/anaconda3/envs/tomopt/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/cernbox/mode_muon_tomography/tomopt/volume/volume.py in forward(self, mu)
#      66     def forward(self, mu: MuonBatch) -> None:  # Expand to take volume as input, too
#      67         for l in self.layers:
# ---> 68             l(mu)
#      69             mu.snapshot_xyz()
#      70
#
# ~/anaconda3/envs/tomopt/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/cernbox/mode_muon_tomography/tomopt/volume/layer.py in forward(self, mu)
#     220         for p in self.yield_zordered_panels():
#     221             self.scatter_and_propagate(mu, mu.z - p.z)  # Move to panel
# --> 222             mu.append_hits(p.get_hits(mu), self.pos)
#     223         self.scatter_and_propagate(mu, mu.z - (self.z - self.size))  # Move to bottom of layer
#     224
#
# ~/cernbox/mode_muon_tomography/tomopt/volume/panel.py in get_hits(self, mu)
#      87         xy0 = self.xy - (self.xy_span / 2)  # Low-left of voxel
#      88         rel_xy = mu.xy - xy0
# ---> 89         res = self.get_resolution(mu.xy, mask)
#      90         rel_xy = rel_xy + (torch.randn((len(mu), 2), device=self.device) / res)
#      91
#
# ~/cernbox/mode_muon_tomography/tomopt/volume/panel.py in get_resolution(self, xy, mask)
#      55             raise ValueError(f"{self.resolution} is not a Tensor for some reason.")  # To appease MyPy
#      56         if self.training or not self.realistic_validation:
# ---> 57             g = self.get_gauss()
#      58             res = self.resolution * torch.exp(g.log_prob(xy)) / torch.exp(g.log_prob(self.xy))  # Maybe detach the normalisation?
#      59         else:
#
# ~/cernbox/mode_muon_tomography/tomopt/volume/panel.py in get_gauss(self)
#      49             return torch.distributions.Normal(self.xy, self.xy_span)  # maybe upscale span?
#      50         except ValueError:
# ---> 51             raise ValueError(f"Invalid parameters for Gaussian: loc={self.xy}, scale={self.xy_span}")
#      52
#      53     def get_resolution(self, xy: Tensor, mask: Optional[Tensor] = None) -> Tensor:
#
# ValueError: Invalid parameters for Gaussian: loc=Parameter containing:
# tensor([nan, nan], requires_grad=True), scale=Parameter containing:
# tensor([nan, nan], requires_grad=True)

# %%
for p in volume.parameters(): print(p)
